# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.373763
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 1.293516 analytic: 1.293516, relative error: 2.028147e-09
# numerical: 0.106341 analytic: 0.106341, relative error: 1.985515e-07
# numerical: 0.849085 analytic: 0.849085, relative error: 8.033119e-08
# numerical: -0.022388 analytic: -0.022388, relative error: 4.794598e-07
# numerical: 0.394513 analytic: 0.394513, relative error: 1.698622e-07
# numerical: 2.527310 analytic: 2.527310, relative error: 1.900340e-09
# numerical: 2.911321 analytic: 2.911321, relative error: 1.342725e-08
# numerical: 1.112918 analytic: 1.112918, relative error: 2.614936e-08
# numerical: 0.890938 analytic: 0.890938, relative error: 4.700427e-11
# numerical: 6.995987 analytic: 6.995987, relative error: 1.923126e-08
# numerical: 3.112552 analytic: 3.111594, relative error: 1.539547e-04
# numerical: -1.327190 analytic: -1.342297, relative error: 5.659314e-03
# numerical: -0.244543 analytic: -0.239807, relative error: 9.777661e-03
# numerical: -3.799506 analytic: -3.799743, relative error: 3.129285e-05
# numerical: 0.568009 analytic: 0.580255, relative error: 1.066475e-02
# numerical: -2.347157 analytic: -2.342103, relative error: 1.077841e-03
# numerical: 0.004423 analytic: 0.018823, relative error: 6.194487e-01
# numerical: 3.726500 analytic: 3.730997, relative error: 6.030936e-04
# numerical: 1.706280 analytic: 1.699057, relative error: 2.121105e-03
# numerical: -4.669968 analytic: -4.662181, relative error: 8.344398e-04

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.373763e+00 computed in 0.079311s
# vectorized loss: 2.373763e+00 computed in 0.005488s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

sfm = Softmax()

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

import itertools
learning_rates = np.arange(1e-7, 5e-7,1e-7)
regularization_strengths = np.arange(2.5e4, 5e4,1e4)
it = list(itertools.product(learning_rates,regularization_strengths))

for i,j in it:
    sfm.train(X_train, y_train, learning_rate=i, reg=j,
                          num_iters=1500, verbose=True)
    y_train_pred = sfm.predict(X_train)
    y_val_pred = sfm.predict(X_val)
    print(i,j)
    results[(i,j)]=(np.mean(y_train == y_train_pred),np.mean(y_val == y_val_pred))
    val_acc = np.mean(y_val == y_val_pred)
    if val_acc>best_val:
        best_val = val_acc
        best_softmax = sfm

pass
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 5.336663
# iteration 100 / 1500: loss 3.575888
# iteration 200 / 1500: loss 3.521847
# iteration 300 / 1500: loss 3.311878
# iteration 400 / 1500: loss 3.326251
# iteration 500 / 1500: loss 2.900370
# iteration 600 / 1500: loss 2.724531
# iteration 700 / 1500: loss 3.066199
# iteration 800 / 1500: loss 3.090991
# iteration 900 / 1500: loss 2.862704
# iteration 1000 / 1500: loss 2.811055
# iteration 1100 / 1500: loss 2.906779
# iteration 1200 / 1500: loss 2.771700
# iteration 1300 / 1500: loss 2.782518
# iteration 1400 / 1500: loss 2.483122
# 1e-07 25000.0
# iteration 0 / 1500: loss 2.684240
# iteration 100 / 1500: loss 2.577733
# iteration 200 / 1500: loss 2.478288
# iteration 300 / 1500: loss 2.256741
# iteration 400 / 1500: loss 2.261612
# iteration 500 / 1500: loss 2.440013
# iteration 600 / 1500: loss 2.318595
# iteration 700 / 1500: loss 2.355153
# iteration 800 / 1500: loss 2.423028
# iteration 900 / 1500: loss 2.455375
# iteration 1000 / 1500: loss 2.482138
# iteration 1100 / 1500: loss 2.273440
# iteration 1200 / 1500: loss 2.574255
# iteration 1300 / 1500: loss 2.441302
# iteration 1400 / 1500: loss 2.358508
# 1e-07 35000.0
# iteration 0 / 1500: loss 2.373252
# iteration 100 / 1500: loss 2.293761
# iteration 200 / 1500: loss 2.345168
# iteration 300 / 1500: loss 2.266964
# iteration 400 / 1500: loss 2.310841
# iteration 500 / 1500: loss 2.378876
# iteration 600 / 1500: loss 2.455182
# iteration 700 / 1500: loss 2.333978
# iteration 800 / 1500: loss 2.367042
# iteration 900 / 1500: loss 2.144674
# iteration 1000 / 1500: loss 2.260251
# iteration 1100 / 1500: loss 2.353625
# iteration 1200 / 1500: loss 2.338175
# iteration 1300 / 1500: loss 2.217785
# iteration 1400 / 1500: loss 1.975567
# 1e-07 45000.0
# iteration 0 / 1500: loss 2.330636
# iteration 100 / 1500: loss 2.172441
# iteration 200 / 1500: loss 2.087728
# iteration 300 / 1500: loss 2.113226
# iteration 400 / 1500: loss 2.180189
# iteration 500 / 1500: loss 2.173743
# iteration 600 / 1500: loss 2.158313
# iteration 700 / 1500: loss 2.060212
# iteration 800 / 1500: loss 2.044294
# iteration 900 / 1500: loss 2.138787
# iteration 1000 / 1500: loss 2.132511
# iteration 1100 / 1500: loss 2.225205
# iteration 1200 / 1500: loss 2.339755
# iteration 1300 / 1500: loss 2.010620
# iteration 1400 / 1500: loss 2.167241
# 2e-07 25000.0
# iteration 0 / 1500: loss 2.169792
# iteration 100 / 1500: loss 2.022297
# iteration 200 / 1500: loss 2.061734
# iteration 300 / 1500: loss 2.233050
# iteration 400 / 1500: loss 2.163564
# iteration 500 / 1500: loss 2.034466
# iteration 600 / 1500: loss 1.981353
# iteration 700 / 1500: loss 2.047318
# iteration 800 / 1500: loss 2.010424
# iteration 900 / 1500: loss 2.031380
# iteration 1000 / 1500: loss 1.941926
# iteration 1100 / 1500: loss 2.008631
# iteration 1200 / 1500: loss 2.119837
# iteration 1300 / 1500: loss 2.104910
# iteration 1400 / 1500: loss 2.047041
# 2e-07 35000.0
# iteration 0 / 1500: loss 1.865883
# iteration 100 / 1500: loss 1.988487
# iteration 200 / 1500: loss 2.093409
# iteration 300 / 1500: loss 2.047045
# iteration 400 / 1500: loss 2.058972
# iteration 500 / 1500: loss 2.045739
# iteration 600 / 1500: loss 2.020906
# iteration 700 / 1500: loss 1.978778
# iteration 800 / 1500: loss 1.857352
# iteration 900 / 1500: loss 1.995284
# iteration 1000 / 1500: loss 1.827505
# iteration 1100 / 1500: loss 1.939313
# iteration 1200 / 1500: loss 2.053583
# iteration 1300 / 1500: loss 2.018610
# iteration 1400 / 1500: loss 1.940311
# 2e-07 45000.0
# iteration 0 / 1500: loss 1.827168
# iteration 100 / 1500: loss 2.039845
# iteration 200 / 1500: loss 2.029985
# iteration 300 / 1500: loss 1.964858
# iteration 400 / 1500: loss 1.832387
# iteration 500 / 1500: loss 2.005372
# iteration 600 / 1500: loss 1.749966
# iteration 700 / 1500: loss 1.994876
# iteration 800 / 1500: loss 1.864409
# iteration 900 / 1500: loss 1.815636
# iteration 1000 / 1500: loss 1.893601
# iteration 1100 / 1500: loss 1.972446
# iteration 1200 / 1500: loss 1.926745
# iteration 1300 / 1500: loss 2.004849
# iteration 1400 / 1500: loss 2.024378
# 3e-07 25000.0
# iteration 0 / 1500: loss 1.901524
# iteration 100 / 1500: loss 2.081792
# iteration 200 / 1500: loss 2.042569
# iteration 300 / 1500: loss 1.778022
# iteration 400 / 1500: loss 1.978277
# iteration 500 / 1500: loss 1.882864
# iteration 600 / 1500: loss 1.938933
# iteration 700 / 1500: loss 1.799938
# iteration 800 / 1500: loss 1.847344
# iteration 900 / 1500: loss 1.852272
# iteration 1000 / 1500: loss 1.920085
# iteration 1100 / 1500: loss 1.886786
# iteration 1200 / 1500: loss 1.878063
# iteration 1300 / 1500: loss 1.940718
# iteration 1400 / 1500: loss 1.960134
# 3e-07 35000.0
# iteration 0 / 1500: loss 1.676539
# iteration 100 / 1500: loss 1.845580
# iteration 200 / 1500: loss 1.855422
# iteration 300 / 1500: loss 1.842899
# iteration 400 / 1500: loss 1.900272
# iteration 500 / 1500: loss 1.812134
# iteration 600 / 1500: loss 1.855809
# iteration 700 / 1500: loss 2.001047
# iteration 800 / 1500: loss 1.890449
# iteration 900 / 1500: loss 1.861967
# iteration 1000 / 1500: loss 1.752016
# iteration 1100 / 1500: loss 1.884554
# iteration 1200 / 1500: loss 1.831625
# iteration 1300 / 1500: loss 1.748070
# iteration 1400 / 1500: loss 1.753175
# 3e-07 45000.0
# iteration 0 / 1500: loss 1.898650
# iteration 100 / 1500: loss 1.955279
# iteration 200 / 1500: loss 1.854369
# iteration 300 / 1500: loss 1.816548
# iteration 400 / 1500: loss 1.911318
# iteration 500 / 1500: loss 1.834585
# iteration 600 / 1500: loss 1.848948
# iteration 700 / 1500: loss 1.745359
# iteration 800 / 1500: loss 1.817592
# iteration 900 / 1500: loss 1.690783
# iteration 1000 / 1500: loss 1.729145
# iteration 1100 / 1500: loss 1.835513
# iteration 1200 / 1500: loss 1.973880
# iteration 1300 / 1500: loss 1.781755
# iteration 1400 / 1500: loss 1.972553
# 4e-07 25000.0
# iteration 0 / 1500: loss 1.898865
# iteration 100 / 1500: loss 1.878662
# iteration 200 / 1500: loss 1.829162
# iteration 300 / 1500: loss 1.807887
# iteration 400 / 1500: loss 1.879798
# iteration 500 / 1500: loss 1.784767
# iteration 600 / 1500: loss 1.855498
# iteration 700 / 1500: loss 1.716159
# iteration 800 / 1500: loss 1.812473
# iteration 900 / 1500: loss 1.739507
# iteration 1000 / 1500: loss 1.665076
# iteration 1100 / 1500: loss 1.699169
# iteration 1200 / 1500: loss 1.850878
# iteration 1300 / 1500: loss 1.743167
# iteration 1400 / 1500: loss 1.721949
# 4e-07 35000.0
# iteration 0 / 1500: loss 1.834358
# iteration 100 / 1500: loss 1.826533
# iteration 200 / 1500: loss 1.679833
# iteration 300 / 1500: loss 1.735961
# iteration 400 / 1500: loss 1.762128
# iteration 500 / 1500: loss 1.782783
# iteration 600 / 1500: loss 1.782095
# iteration 700 / 1500: loss 1.684681
# iteration 800 / 1500: loss 1.855678
# iteration 900 / 1500: loss 1.722646
# iteration 1000 / 1500: loss 1.617287
# iteration 1100 / 1500: loss 1.724227
# iteration 1200 / 1500: loss 1.845125
# iteration 1300 / 1500: loss 1.779725
# iteration 1400 / 1500: loss 1.737309
# 4e-07 45000.0
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.249755 val accuracy: 0.246000
# lr 1.000000e-07 reg 3.500000e+04 train accuracy: 0.278163 val accuracy: 0.274000
# lr 1.000000e-07 reg 4.500000e+04 train accuracy: 0.294388 val accuracy: 0.290000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.316816 val accuracy: 0.305000
# lr 2.000000e-07 reg 3.500000e+04 train accuracy: 0.332020 val accuracy: 0.309000
# lr 2.000000e-07 reg 4.500000e+04 train accuracy: 0.343653 val accuracy: 0.327000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.355469 val accuracy: 0.342000
# lr 3.000000e-07 reg 3.500000e+04 train accuracy: 0.366612 val accuracy: 0.351000
# lr 3.000000e-07 reg 4.500000e+04 train accuracy: 0.372633 val accuracy: 0.371000
# lr 4.000000e-07 reg 2.500000e+04 train accuracy: 0.378531 val accuracy: 0.384000
# lr 4.000000e-07 reg 3.500000e+04 train accuracy: 0.387367 val accuracy: 0.389000
# lr 4.000000e-07 reg 4.500000e+04 train accuracy: 0.392837 val accuracy: 0.381000
# best validation accuracy achieved during cross-validation: 0.389000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.367000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
